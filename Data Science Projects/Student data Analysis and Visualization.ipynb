# %% [markdown]
# # Student data Analysis and Visualization

# %% [markdown]
# ## Introduction

# %% [markdown]
#  Welcome to Student_dataset project.Here we have a dataset called student which has the details of the students excluding their names.
# In this project,we are going to do the following stpes.
#
# First,we need to import the required modules such as numpy,pandas,matplotlib and seaborn.
#
# Then we are going to read the dataset which can be csv file or excel file.
#
# After read the dataset,we are going to analyse the dataset by various angles.
#
# After completing the analyis process,we use the visualizing tool to do the visualization process.
#
# Here we use various plots to visualize such as,
# 1.Countplot
#
# 2.Boxplot
#
# 3.Violinplot
#
# 4.Barplot
#
# 5.Distplot
#
# 6.Swarmpot
#
# 7.Catplot
#
# 8.Jointplot
#
# 9.Pairplot
#
# 10.FacetGrid

# %% [markdown]
# # Importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Read the "data_student.csv" file using read_csv() (Hint: indicate ';' as the seperator and indicate not to read in index column) and check its head:

# %%
data_student=pd.read_csv("data_student.csv", sep=';',index_col=0)
data_student
# Out:
#     school sex  age famsize Pstatus  Medu      Mjob  reason  traveltime  \
# 0       GP   F   18     GT3       A     4   at_home  course           2
# 1       GP   F   17     GT3       T     1   at_home  course           1
# 2       GP   F   15     LE3       T     1   at_home   other           1
# 3       GP   F   15     GT3       T     4    health    home           1
# 4       GP   F   16     GT3       T     3     other    home           1
# ..     ...  ..  ...     ...     ...   ...       ...     ...         ...
# 390     MS   M   20     LE3       A     2  services  course           1
# 391     MS   M   17     LE3       T     3  services  course           2
# 392     MS   M   21     GT3       T     1     other  course           1
# 393     MS   M   18     LE3       T     3  services  course           3
# 394     MS   M   19     LE3       T     1     other  course           1
#
#      studytime  freetime  health  absences  G2  G3
# 0            2         3       3         6   6   6
# ...

# %% [markdown]
# ## Summarize the dataset

# %%
data_student.head()
# Out:
#   school sex  age famsize Pstatus  Medu     Mjob  reason  traveltime  \
# 0     GP   F   18     GT3       A     4  at_home  course           2
# 1     GP   F   17     GT3       T     1  at_home  course           1
# 2     GP   F   15     LE3       T     1  at_home   other           1
# 3     GP   F   15     GT3       T     4   health    home           1
# 4     GP   F   16     GT3       T     3    other    home           1
#
#    studytime  freetime  health  absences  G2  G3
# 0          2         3       3         6   6   6
# 1          2         3       3         4   5   6
# 2          2         3       3        10   8  10
# 3          3         2       5         2  14  15
# 4          2         3       5         4  10  10

# %%
data_student.tail()
# Out:
#     school sex  age famsize Pstatus  Medu      Mjob  reason  traveltime  \
# 390     MS   M   20     LE3       A     2  services  course           1
# 391     MS   M   17     LE3       T     3  services  course           2
# 392     MS   M   21     GT3       T     1     other  course           1
# 393     MS   M   18     LE3       T     3  services  course           3
# 394     MS   M   19     LE3       T     1     other  course           1
#
#      studytime  freetime  health  absences  G2  G3
# 390          2         5       4        11   9   9
# 391          1         4       2         3  16  16
# 392          1         5       3         3   8   7
# 393          1         4       5         0  12  10
# 394          1         2       5         5   9   9

# %%
data_student.describe()
# Out:
#               age        Medu  traveltime   studytime    freetime      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    1.448101    2.035443    3.235443    3.554430
# std      1.276043    1.094735    0.697505    0.839240    0.998862    1.390303
# min     15.000000    0.000000    1.000000    1.000000    1.000000    1.000000
# 25%     16.000000    2.000000    1.000000    1.000000    3.000000    3.000000
# 50%     17.000000    3.000000    1.000000    2.000000    3.000000    4.000000
# 75%     18.000000    4.000000    2.000000    2.000000    4.000000    5.000000
# max     22.000000    4.000000    4.000000    4.000000    5.000000    5.000000
#
#          absences          G2          G3
# count  395.000000  395.000000  395.000000
# mean     5.708861   10.713924   10.415190
# std      8.003096    3.761505    4.581443
# min      0.000000    0.000000    0.000000
# 25%      0.000000    9.000000    8.000000
# ...

# %%
data_student.columns
# Out:
# Index(['school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu', 'Mjob', 'reason',
#        'traveltime', 'studytime', 'freetime', 'health', 'absences', 'G2',
#        'G3'],
#       dtype='object')

# %%
data_student.shape
# Out:
# (395, 15)

# %%
data_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   famsize     395 non-null    object
#  4   Pstatus     395 non-null    object
#  5   Medu        395 non-null    int64
#  6   Mjob        395 non-null    object
#  7   reason      395 non-null    object
#  8   traveltime  395 non-null    int64
#  9   studytime   395 non-null    int64
#  10  freetime    395 non-null    int64
#  11  health      395 non-null    int64
#  12  absences    395 non-null    int64
#  13  G2          395 non-null    int64
#  14  G3          395 non-null    int64
# dtypes: int64(9), object(6)
# memory usage: 49.4+ KB

# %% [markdown]
# ## Analyse the data

# %% [markdown]
# ### Find how many students are female

# %%
data_student[data_student["sex"]=="F"].count()
# Out:
# school        208
# sex           208
# age           208
# famsize       208
# Pstatus       208
# Medu          208
# Mjob          208
# reason        208
# traveltime    208
# studytime     208
# freetime      208
# health        208
# absences      208
# G2            208
# G3            208
# dtype: int64

# %% [markdown]
# ### Find how many students are male and age is above 19

# %%
data_student[(data_student["sex"]=="M") & (data_student["age"]>19)].count()
# Out:
# school        4
# sex           4
# age           4
# famsize       4
# Pstatus       4
# Medu          4
# Mjob          4
# reason        4
# traveltime    4
# studytime     4
# freetime      4
# health        4
# absences      4
# G2            4
# G3            4
# dtype: int64

# %% [markdown]
# ### Find the maximum G3 score

# %%
data_student["G3"].max()
# Out:
# 20

# %% [markdown]
# ### Find out the G2 scoreof the student who got the maximum G3 score

# %%
data_student[data_student["G3"]==20]["G2"]
# Out:
# 47    19
# Name: G2, dtype: int64

# %% [markdown]
# ### Find the location of a student who got G2 score of 19

# %%
data_student.loc[data_student["G2"]==19]
# Out:
#     school sex  age famsize Pstatus  Medu     Mjob      reason  traveltime  \
# 47      GP   M   16     GT3       T     4   health  reputation           1
# 110     GP   M   15     LE3       A     4  teacher      course           1
# 113     GP   M   15     LE3       T     4  teacher      course           1
#
#      studytime  freetime  health  absences  G2  G3
# 47           4         2       2         4  19  20
# 110          1         5       4         6  19  19
# 113          1         5       3        10  19  19

# %% [markdown]
# ### Find the studytime,freetime,traveltime of the students who got G2 score and G3 score as 15

# %%
data_student[(data_student["G2"]==15)&(data_student["G3"]==15)][["studytime","freetime","traveltime"]]
# Out:
#      studytime  freetime  traveltime
# 5            2         4           1
# 9            2         5           1
# 21           1         4           1
# 56           2         3           1
# 57           2         2           1
# 65           2         4           3
# 70           4         3           2
# 83           2         3           2
# 96           1         3           2
# 120          2         2           1
# 158          1         2           3
# 187          2         2           1
# 195          2         3           1
# 215          2         4           2
# 226          2         3           1
# 249          1         3           1
# 291          3         2           1
# 324          3         3           2
# 335          3         4           1
# 342          2         3           1
# 348          3         4           1
# 363          2         3           1
# 378          2         1           1

# %% [markdown]
# ### Calculate the total G3 score by sex

# %%
group=data_student["G3"].groupby(data_student["sex"])
group.sum()
# Out:
# sex
# F    2073
# M    2041
# Name: G3, dtype: int64

# %% [markdown]
# ### Calculate the average G2 score by school

# %%
group=data_student["G2"].groupby(data_student["school"])
group.mean()
# Out:
# school
# GP    10.782235
# MS    10.195652
# Name: G2, dtype: float64

# %% [markdown]
# ### Calculate the sum of G2 and G3 score by age

# %%
group=data_student[["G2","G3"]].groupby(data_student["age"])
group.sum()
# Out:
#        G2    G3
# age
# 15    932   923
# 16   1163  1147
# 17   1027  1007
# 18    831   783
# 19    222   197
# 20     41    42
# 21      8     7
# 22      8     8

# %% [markdown]
# ### How many unique Mjobs are there?

# %%
data_student["Mjob"].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %% [markdown]
# ### Get general information about DataFrame:

# %%
data_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   famsize     395 non-null    object
#  4   Pstatus     395 non-null    object
#  5   Medu        395 non-null    int64
#  6   Mjob        395 non-null    object
#  7   reason      395 non-null    object
#  8   traveltime  395 non-null    int64
#  9   studytime   395 non-null    int64
#  10  freetime    395 non-null    int64
#  11  health      395 non-null    int64
#  12  absences    395 non-null    int64
#  13  G2          395 non-null    int64
#  14  G3          395 non-null    int64
# dtypes: int64(9), object(6)
# memory usage: 49.4+ KB

# %% [markdown]
# ### Get the mean value of final grade(G3)

# %%
data_student["G3"].mean()
# Out:
# 10.415189873417722

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Plot the number of students for each school and categorize it by sex: (Hint: countplot)

# %%
sns.countplot(x='school',data=data_student,hue="sex")
# Out:
# <Axes: xlabel='school', ylabel='count'>

# %% [markdown]
# ### Plot age distribution of the students(include kde)

# %%
sns.distplot(x=data_student['age'],kde=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Plot average of students for each school:

# %%
sns.barplot(x='school',y='age',data=data_student)
# Out:
# <Axes: xlabel='school', ylabel='age'>

# %% [markdown]
# ### Plot the quartiles of final grade(G3) of the students categorized by mother's education(Medu) (Hint:boxplot)
#
# info:
#
# 0 - None
#
# 1 - primary education(4th grade)
#
# 2 - 5th to 9th grade
#
# 3 - secondary education
#
# 4 - higher education

# %%
sns.boxplot(x="Medu",y="G3",data=data_student)
# Out:
# <Axes: xlabel='Medu', ylabel='G3'>

# %% [markdown]
# ### Plot probability density with regards to final grade (G3) and mother's job (Mjob) and consider sex by selecting split=True:  (Hint:violinplot)

# %%
#using violinplot  -- we use violinplot because only violin plot has split attribute
sns.violinplot(x="Mjob",y="G3",data=data_student,hue="sex",split=True)
# Out:
# <Axes: xlabel='Mjob', ylabel='G3'>

# %%
#using barplot
sns.barplot(x="Mjob",y="G3",data=data_student,hue="sex")
# Out:
# <Axes: xlabel='Mjob', ylabel='G3'>

# %%
#using boxplot
sns.boxplot(x="Mjob",y="G3",data=data_student,hue="sex")
# Out:
# <Axes: xlabel='Mjob', ylabel='G3'>

# %% [markdown]
# ### Plot density distribution of the grades (both G2,G3 on the same canvas) with regards to health but this time we want to see every data as a point in our plot: (Hint: swarmplot,subplot)
#
# info: health status(numeric: from 1 - very bad to 5 - very good)

# %%
fig,axes=plt.subplots(1,2,figsize=(13,5))

sns.swarmplot(x="health",y="G2",data=data_student,ax=axes[0])
sns.swarmplot(x="health",y="G3",data=data_student,ax=axes[1])
# Out:
# <Axes: xlabel='health', ylabel='G3'>

# %% [markdown]
# ### Do the same for the absences and travel time (single plot is enough)

# %%
 sns.swarmplot(x="traveltime",y="absences",data=data_student)
# Out:
# <Axes: xlabel='traveltime', ylabel='absences'>

# %% [markdown]
# ### Plot the final grade (G3) with respect to the parental status(Pstatus) and family size(famsize) using FacetGrid and distplot (set kde=False)
#
# info:

# %% [markdown]
# LE3 - less than and equal to 3

# %% [markdown]
# GT3 - Greater than 3

# %% [markdown]
# A - Apart

# %% [markdown]
# T - Together

# %%
facet= sns.FacetGrid(data_student,row="Pstatus",col="famsize")

facet.map(sns.distplot,"G3",kde=False)

# %% [markdown]
# ### Plot a categorical relationship between study time(studytime) and mean of final grade (G3) (Hint: barplot)

# %%
sns.barplot(x="studytime",y="G3",data=data_student,estimator=np.mean)
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %% [markdown]
# ### Plot a relationship between max, midterm grade(G2) and reason for closing the school(reason) and categorize it by sex:        (Hint: We need barplot but let us use catplot to reach the same plot)

# %%
#using barplot
sns.barplot(x="reason",y="G2",data=data_student,hue="sex",estimator=np.max)
# Out:
# <Axes: xlabel='reason', ylabel='G2'>

# %%
#using catplot
sns.catplot(x="reason",y="G2",data=data_student,kind="bar",hue="sex",estimator=np.max)

# %% [markdown]
# ### Plot the distribution of the final grade(G3) of the students using kde. Plot for both gender type on the same plot:  (Hint: distplot using logical masking could come in handy.)

# %%
sns.distplot(data_student[data_student['sex']=="M"]["G3"],label='Male',color="red",hist=True)
sns.distplot(data_student[data_student['sex']=="F"]["G3"],label="Female",color="yellow",hist=True)
# Out:
# <Axes: xlabel='G3', ylabel='Density'>

# %% [markdown]
# ### This time plot the distribution of midterm grade(G2) using kde together for each freetime amount: (Hint: Previously we had 2 plot together, this time we had 5, so let's use for loop instead)

# %%
data_student["freetime"].nunique()
# Out:
# 5

# %%
for time in data_student["freetime"].unique():
    sns.distplot(data_student[data_student["freetime"]==time]["G3"],label=time,hist=False)

# %% [markdown]
# ### Create a jointplot for relationship between midterm(G2) and final grades(G3):

# %%
sns.jointplot(x="G2",data=data_student,y="G3",kind="kde")

# %% [markdown]
# ### Let's do the same for absences and midterm grade (G2) but this time with hex:

# %%
sns.jointplot(x="absences",y="G2",data=data_student,kind="hex")

# %% [markdown]
# ### Plot the relationship between midterm(G2),final grade(G3) and absences:  (Hint: we have more than 2 columns to pair)

# %%
sns.pairplot(data_student[['G2','G3','absences']])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have made various analysis by using pandas and done visualizations by using matplotlib and seaborn on different perspectives.
